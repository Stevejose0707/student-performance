# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
sp=pd.read_csv("C:/Users/Steve Jose/Downloads/archive (7)/Student_Performance.csv")
sp
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
sp.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
sp.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
sp.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
sp.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
sp['Extracurricular Activities']=le.fit_transform(sp['Extracurricular Activities'])

# %%
x=sp.iloc[:,:-1]

# %%
y=sp.iloc[:,-1]

# %%
plt.scatter(sp['Extracurricular Activities'],sp['Performance Index'])

# %%
import seaborn as sns
sns.regplot(x=sp['Extracurricular Activities'],y=sp['Performance Index'])
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Performance Index'>

# %%
sns.regplot(x=sp['Hours Studied'],y=sp['Performance Index'])
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sns.regplot(x=sp['Previous Scores'],y=sp['Performance Index'])
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Performance Index'>

# %%
sns.regplot(x=sp['Sleep Hours'],y=sp['Performance Index'])
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance Index'>

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xtrain,ytrain)
p=model.predict(xtest)
p
# Out:
# array([54.74728554, 22.61884434, 47.93665124, ..., 33.42451751,
#        67.92578967, 31.20587077])

# %%
print('slope is ',list(zip(x,model.coef_)))
# Out:
# slope is  [('Hours Studied', 2.858952230523516), ('Previous Scores', 1.01551979428808), ('Extracurricular Activities', 0.5817128541736176), ('Sleep Hours', 0.47967675981703306), ('Sample Question Papers Practiced', 0.19039415655051095)]

# %%
print('contant is ',model.intercept_)
# Out:
# contant is  -33.83654380714167
